# %%
## 패키지 import 
import pymysql

print(pymysql.version_info) # 모듈 버전 확인

## DB연동을 위한 설정 정보
config = {      # DB연동을 위한 환경변수
    'host' : '127.0.0.1',  # 각자의 접속 DB주소, 127.0.0.1 
    'user' : 'scott',
    'password' : 'tiger',
    'database' : 'work',
    'port' : 3306,
    'charset' : 'utf8',
    'use_unicode' : True
}

try:
    ## DB연동 객체 생성
    # 1. 직접 입력:(host='127.0.0.1',user='scott',password='tiger' 등등....)
    # 2. 사전 설정된 정보를 적용 
    conn = pymysql.connect(**config) 
    # sql실행 객체 - 커서 객체 (cursor)
    cursor = conn.cursor() 
    ## 테이블 조회
    sql = "show tables"
    cursor.execute(sql) 
    tables = cursor.fetchall() # 리스트로 반환
    
    ## table유무 확인 
    if tables: 
        print("table 있음\n",tables)
    else: 
        print("table 없음")
         
except Exception as e:
    print("DB연동 에러 :",e)
    conn.rollback() ## insert,update,delete
finally:
    cursor.close()
    conn.close()
# Out:
# (1, 4, 0, 'final', 0)
# table 있음
#  (('goods',),)

# %%
##mysql CRUD 동작
# 1. 기존의 goods 테이블 삭제 
# 2. python 코드를 이용하여 DB연결 객체를 생성
# 3. DB안에 goods라는 테이블을 생성

# 4. 생성된 goods 테이블에 레코드 추가 작성
#    작성시 input을 이용하여 code,name,su,dan 를 입력받아서 레코드 추가
# 5. 전체 목록 보기 (전체 목록을 출력한 후에 전체 목록 갯수도 출력) 
# 6. 상품명 조회 (상품명을 입력 받아 해당 상품명에 따른 레코드를 출력)

# %%
## 패키지 import 
import pymysql

print(pymysql.version_info) # 모듈 버전 확인

## DB연동을 위한 설정 정보
config = {      # DB연동을 위한 환경변수
    'host' : '127.0.0.1',  # 각자의 접속 DB주소, 127.0.0.1 
    'user' : 'scott',
    'password' : 'tiger',
    'database' : 'work',
    'port' : 3306,
    'charset' : 'utf8',
    'use_unicode' : True
}

try:
    # 연결 객체 생성
    conn = pymysql.connect(**config) 
    # sql실행 객체 - 커서 객체 (cursor)
    cursor = conn.cursor() 
    ## 테이블 조회
    # sql = "show tables"
    # cursor.execute(sql) 
    # tables = cursor.fetchall() # 리스트로 반환
    # 테이블 삭제
    # sql = "drop table if exists goods"
    # cursor.execute(sql)
    # 테이블 생성 
    # sql = "create table if not existswork.goods(code int primary key,name varchar(20) not null,su int,dan int)" 
    # cursor.execute(sql)
    # 레코드 작성 
    # code = int(input("코드를 입력하세요:")) 
    # good = input("상품 이름을 입력하세요:") 
    # su = int(input("상품 수를 입력하세요:")) 
    # dan = int(input("상품 단가를 입력하세요:")) 
    # sql = f"insert into goods values({code},'{good}',{su},{dan})" 
    # cursor.execute(sql) 
    # conn.commit() 
    # 전체 목록 보기
    # sql = "select * from goods" 
    # cursor.execute(sql) 
    # lst = cursor.fetchall() 
    # for row in lst:
    #     print("%d  %s  %d  %d" % row)
    # print("검색 레코드 수 :",len(lst))
    # 상품명 조회 
    name = input("조회할 상품명 입력 :")
    sql = f"select *from goods where name like '%{name}%'"
    cursor.execute(sql)
    record = cursor.fetchall()
    if record:
        # 레코드가 1개 이상 존재함
        for row in record:     
            print("상품 정보 :",row[0],row[1],row[2],row[3])
    else:
        print("해당 상품이 없습니다.") 
except Exception as e:
    print("DB연동 에러 :",e)
    conn.rollback() ## insert,update,delete
finally:
    cursor.close()
    conn.close()
# Out:
# (1, 4, 0, 'final', 0)
# 상품 정보 : 1 컴퓨터 2 200000

# %%
# 위의 문제를 이용하여 다음과 같은 메뉴로 동작하는 DB프로그램 작성
# -------메뉴------
# 1. 상품 등록
# 2. 상품 조회(전체)
# 3. 상품 조회(상품명으로 조회)
# 4. 상품 수정(code)
# 5. 상품 삭제(코드) 
# 0. 프로그램 종료 
# 조건 1. 각 기능을 함수로 구현하세요.
#     2. 반복 기능을 사용하여 구현하세요.(while을 이용한 무한 반복)
import os
import pymysql


config = {      # DB연동을 위한 환경변수
    'host' : '127.0.0.1',  # 각자의 접속 DB주소, 127.0.0.1 
    'user' : 'scott',
    'password' : 'tiger',
    'database' : 'work',
    'port' : 3306,
    'charset' : 'utf8',
    'use_unicode' : True
}

conn = pymysql.connect(**config) 
cursor = conn.cursor()
def goods():
    while True:
        os.system('cls')
        num = int(input("-------메뉴------\n1. 상품 등록\n2. 상품 조회(전체)\n3. 상품 조회(상품명으로 조회)\n4. 상품 수정(code)\n5. 상품 삭제(코드)\n0. 프로그램 종료 "))
        if num == 1:
            code = int(input("코드를 입력하세요:")) 
            good = input("상품 이름을 입력하세요:") 
            su = int(input("상품 수를 입력하세요:")) 
            dan = int(input("상품 단가를 입력하세요:")) 
            sql = f"insert into goods values({code},'{good}',{su},{dan})" 
            cursor.execute(sql) 
            conn.commit() 
        elif num == 2:
            sql = "select * from goods" 
            cursor.execute(sql) 
            lst = cursor.fetchall() 
            for row in lst:
                print("%d  %s  %d  %d" % row) 
        elif num ==3:
            name = input("조회할 상품명 입력 :")
            sql = f"select *from goods where name like '%{name}%'"
            cursor.execute(sql)
            record = cursor.fetchall()
            if record:
                for row in record:     
                    print("상품 정보 :",row[0],row[1],row[2],row[3])
            else:
                print("해당 상품이 없습니다.")
        elif num == 4:
            code = int(input("수정할 상품의 코드를 입력 :"))
            su = int(input("수량 입력 :"))
            dan = int(input("단가를 입력 :"))
            check = input("수정하시겠습니까? y/n")
            if check == 'y':
                sql = f"update goods set su = {su},dan = {dan} where code={code}"
                cursor.execute(sql)
                conn.commit()
                print("수정되었습니다.")
            else :
                print(num)
        elif num == 5:
            code = int(input("삭제할 상품의 코드 입력 :"))
            sql = f"delete from goods where code ={code}"
            cursor.execute(sql)
            print("상품을 삭제했습니다.")
        elif num == 0:
            print("프로그램을 종료 합니다.") 
            break 
        else : 
            print('입력 오류, 다시입력하세요!!!')
            os.system('pause')

# %%
import pymysql
import os
import sys

def CreateTable(): 
    try:
        conn = pymysql.connect(**config) 
        cursor = conn.cursor()
        sql = "create table if not existswork.goods(code int primary key,name varchar(20) not null,su int,dan int)" 
        cursor.execute(sql)
    except Exception as e :
        print("에러:",e)
    finally:
        cursor.close()
        conn.close() 
def Insert(code,name,su,dan): 
    try:
        conn = pymysql.connect(**config) 
        cursor = conn.cursor() 
        sql = f"insert into goods values({code},'{name}',{su},{dan})" 
        cursor.execute(sql) 
        conn.commit()  
    except Exception as e :
        print("insert 실패:",e)
    finally:
        cursor.close()
        conn.close() 
def SelectAll():
    try:
        conn = pymysql.connect(**config) 
        cursor = conn.cursor()
        sql = "select * from goods" 
        cursor.execute(sql) 
        rows = cursor.fetchall()
        print("code\tname\t수량\t단가")
        for row in rows:
            print("{}\t{}\t{}\t{}\t".format(row[0],row[1],row[2],row[3]))
        print("총 상품 수량 :", len(rows))
    except Exception as e :
        print("전체 조회 실패:",e)
    finally:
        cursor.close()
        conn.close()
def SelectOne(name):
    try:
        conn = pymysql.connect(**config) 
        cursor = conn.cursor()
        sql = f"select * from goods where name like '%{name}%')" 
        rows = cursor.execute(sql)
        if rows:
            print("code\tname\t수량\t단가")
            for row in rows: 
                print("{}\t{}\t{}\t{}\t".format(row[0],row[1],row[2],row[3]))
        else:
            print("해당 상품이 없습니다.")
    except Exception as e :
        print("상품 조회 실패:",e)
    finally:
        cursor.close()
        conn.close()
def Update(code):
    try:
        conn = pymysql.connect(**config) 
        cursor = conn.cursor()
        su = int(input("변경할 수량 입력 :"))
        dan = int(input("변경할 단가를 입력 :"))
        check = input("수정하시겠습니까? y/n")
        if check == 'y':
            sql = f"update goods set su = {su},dan = {dan} where code={code}"
            cursor.execute(sql)
            conn.commit()
            print("수정되었습니다.")
        else :
            print("수정이 취소되었습니다.")
    except Exception as e :
        print("업데이트 실패:",e)
    finally:
        cursor.close()
        conn.close()
def Delete(code):
    try:
        conn = pymysql.connect(**config) 
        cursor = conn.cursor()
        sql = f"delete from goods where code = {code}"
        del_sel = input("정말 삭제하시겠습니까? y/n :")
        if del_sel.lower() == 'y':
            cursor.execute(sql)
            conn.commit()
        else: 
            print("삭제를 취소합니다.")       
    except Exception as e :
        print("삭제 실패:",e)
    finally:
        cursor.close()
        conn.close()

while True: 
    os.system('cls')
    print("=========메뉴=======")
    print("1.상품 등록")
    print("2. 상품 조회(전체)")
    print("3. 상품 조회(상품명으로)")
    print("4. 상품 수정")
    print("5. 상품 삭제")
    print("0. 종료")
    CreateTable()
    
    
    sel = input("메뉴를 선택하세요 :")
    match sel:
        case '1':
            print("레코드 추가 정보를 입력")
            code = int(input("코드 입력 : "))
            name = input("상품명 입력 : ")
            su = int(input("수량 입력 : "))
            dan = int(input("단가 입력 : "))
            Insert(code,name,su,dan)
        case '2':
            print("전체 상품 조회")
            SelectAll()
        case '3':
            print("개별 상품 조회")
            name = input("상품명을 입력하세요 :")
            SelectOne(name)
        case '4':
            print("상품 정보 수정")
            code = int(input("변경할 상품 코드 입력 :"))
            Update(code)
        case '5':
            code = int(input("삭제할 상품 코드 입력 :"))
            Delete(code)
        case '0':
            print("프로그램을 종료합니다.")
            os.system("pause")
            sys.exit(0)  
        case _:
            print("메뉴 선택을 잘못했습니다.")
            os.system("pause")

# %%
### 앞서 만들어진 함수를 class로 구성하세요. 
# # -------메뉴------
# 1. 상품 등록
# 2. 상품 조회(전체)
# 3. 상품 조회(상품명|code)
#       - 상품명 : 상품명으로 조회 
#       - 코드 : 코드를 이용해서 조회
# 4. 상품 수정(code)
# 5. 상품 삭제(코드) 
# 0. 프로그램 종료 

import os
import pymysql


config = {      # DB연동을 위한 환경변수
    'host' : '127.0.0.1',  # 각자의 접속 DB주소, 127.0.0.1 
    'user' : 'scott',
    'password' : 'tiger',
    'database' : 'work',
    'port' : 3306,
    'charset' : 'utf8',
    'use_unicode' : True
}

class Product:       
    def __init__(self,config):
        self.config = config
        #print(type(self.config))
        self.conn = pymysql.connect(**self.config)
        self.cursor = self.conn.cursor()
        print("객체 생성 확인 : ", self.conn)
        print("커서 객체 확인 : ", self.cursor)

    def createTable(self):
        sql ="""create table if not exists goods(
            code int primary key,
            name varchar(30) not null,
            su int default 0,
            dan int default 0
        )"""
        self.cursor.execute(sql)
        self.conn.commit()
    
    def Insert(self,code,name,su,dan):
        sql = f"insert into goods values({code},'{name}',{su},{dan})"
        self.cursor.execute(sql)
        self.conn.commit()
    
    def SelectAll():
        sql = "select * from goods" 
        self.cursor.execute(sql) 
        rows = cursor.fetchall()
        print("code\tname\t수량\t단가")
        for row in rows:
            print("{}\t{}\t{}\t{}\t".format(row[0],row[1],row[2],row[3]))
        print("총 상품 수량 :", len(rows))
       
    def SelectOne(self,name):
        self.name = name 
        sql = f"select * from goods where name like '%{name}%')" 
        self.cursor.execute(sql)
        rows = self.cursor.fetchall()
        if rows:
            print("code\tname\t수량\t단가")
            for row in rows: 
                print("{}\t{}\t{}\t{}\t".format(row[0],row[1],row[2],row[3]))
        else:
            print("해당 상품이 없습니다.")
      
    def Update(code):
        su = int(input("변경할 수량 입력 :"))
        dan = int(input("변경할 단가를 입력 :"))
        check = input("수정하시겠습니까? y/n")
        if check == 'y':
            sql = f"update goods set su = {su},dan = {dan} where code={code}"
            self.cursor.execute(sql)
            self.conn.commit()
            print("수정되었습니다.")
        else :
            print("수정이 취소되었습니다.")
       
    def Delete(code):

        sql = f"delete from goods where code = {code}"
        del_sel = input("정말 삭제하시겠습니까? y/n :")
        if del_sel.lower() == 'y':
            self.cursor.execute(sql)
            self.conn.commit()
        else: 
            print("삭제를 취소합니다.")       
     
    
x = Product(config)
x.Insert(6, '키보드', 10, 20000)
    
while True: 
    os.system('cls')
    print("=========메뉴=======")
    print("1.상품 등록")
    print("2. 상품 조회(전체)")
    print("3. 상품 조회(상품명으로)")
    print("4. 상품 수정")
    print("5. 상품 삭제")
    print("0. 종료")
    CreateTable()
    
    
    sel = input("메뉴를 선택하세요 :")
    match sel:
        case '1':
            print("레코드 추가 정보를 입력")
            code = int(input("코드 입력 : "))
            name = input("상품명 입력 : ")
            su = int(input("수량 입력 : "))
            dan = int(input("단가 입력 : "))
            Insert()
        case '2':
            print("전체 상품 조회")
            SelectAll()
        case '3':
            print("개별 상품 조회")
            name = input("상품명을 입력하세요 :")
            SelectOne()
        case '4':
            print("상품 정보 수정")
            code = int(input("변경할 상품 코드 입력 :"))
            Update(code)
        case '5':
            code = int(input("삭제할 상품 코드 입력 :"))
            Delete(code)
        case '0':
            print("프로그램을 종료합니다.")
            os.system("pause")
            break 
        case _:
            print("메뉴 선택을 잘못했습니다.")
            os.system("pause")
# Out:
# =========메뉴=======
# 1.상품 등록
# 2. 상품 조회(전체)
# 3. 상품 조회(상품명으로)
# 4. 상품 수정
# 5. 상품 삭제
# 0. 종료
# sh: cls: command not found
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yunbeen/Desktop/ybfolder/빅데이터:자바 자료/python /pythonproject/Day18/Day18.ipynb Cell 6' in <cell line: 112>()
#     <a href='vscode-notebook-cell:/Users/yunbeen/Desktop/ybfolder/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%3A%EC%9E%90%EB%B0%94%20%EC%9E%90%EB%A3%8C/python%20/pythonproject/Day18/Day18.ipynb#ch0000005?line=118'>119</a> print("5. 상품 삭제")
#     <a href='vscode-notebook-cell:/Users/yunbeen/Desktop/ybfolder/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%3A%EC%9E%90%EB%B0%94%20%EC%9E%90%EB%A3%8C/python%20/pythonproject/Day18/Day18.ipynb#ch0000005?line=119'>120</a> print("0. 종료")
# ...
